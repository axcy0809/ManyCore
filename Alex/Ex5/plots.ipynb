17.6236,
18.0336,
18.0336,
17.6236,
16.7892,
15.5005,
13.7119,
11.3598,
8.36161,
4.61505],[4.16777,
7.49623,
10.1256,
12.1688,
13.7119,
14.8185,
15.533,
15.8835,
15.8835,
15.533,
14.8185,
13.7119,
12.1688,
10.1256,
7.49623,
4.16777],[3.55981,
6.32988,
8.47776,
10.1256,
11.3598,
12.24,
12.8065,
13.0838,
13.0838,
12.8065,
12.24,
11.3598,
10.1256,
8.47776,
6.32988,
3.55981],[2.74158,
4.78573,
6.32988,
7.49623,
8.36161,
8.97536,
9.369,
9.56139,
9.56139,
9.369,
8.97536,
8.36161,
7.49623,
6.32988,
4.78573,
2.74158],[1.62079,
2.74158,
3.55981,
4.16777,
4.61505,
4.9308,
5.1328,
5.2314,
5.2314,
5.1328,
4.9308,
4.61505,
4.16777,
3.55981,
2.74158,
1.62079]])

# %%
plt.imshow(sol, cmap='hot', interpolation='nearest')
plt.savefig("Bilder/solution_16x16")
plt.title("solution on a 16x16 grid")
plt.xlabel("M")
plt.ylabel("N")
plt.show()

# %%
import seaborn as sns;

sns.heatmap(sol)
plt.title("solution on a 16x16 grid")
plt.xlabel("M")
plt.ylabel("N")
plt.savefig("Bilder/solution_16x16")

# %%
N = [3,8,16,48,100,200,300,400,500,800]
N2 = []

for i in N:
    N2.append(i*i)

#CPU_ass = [1.3e-05, 4e-06, 8.7e-05, 0.00037, 0.002074, 0.003743, 0.007686, 0.01264, 0.024518]
#CPU_GD = [ 0.001967, 0.006312, 0.049569,0.104405, 0.229118, 0.349307, 0.441362, 0.547568, 1.2717]

CPU_ass = [1.3e-05, 3e-06, 9e-06, 0.000108, 0.000572, 0.001848, 0.003273, 0.007729, 0.013288, 0.023871]
CPU_GD = [ 0.001967, 0.006304, 0.016293, 0.049261, 0.106773, 0.225449, 0.340329, 0.461494, 0.577733, 1.27205]



GPU_ass = [5.9e-05, 5.7e-05, 6.3e-05, 0.000134, 0.000497, 0.001592, 0.003661, 0.005892, 0.00901, 0.021704]
GPU_GD = [0.001886, 0.006395, 0.016175, 0.050557, 0.10634, 0.222855, 0.342032, 0.442232, 0.544581, 0.742223]


plt.semilogy(N,GPU_GD, label = "GPU_GD", marker='x')
plt.semilogy(N,CPU_GD, label = "CPU_GD", marker='x')
plt.legend()
plt.grid()
plt.title("Runtime GPU_GD vs CPU_GD")
plt.xlabel("length of vector")
plt.ylabel("time[s]")
plt.savefig("Bilder/runtime_GPU_vs_CPU")

plt.figure()
plt.semilogy(N,GPU_ass, label = "GPU_assemble", marker='x')
plt.semilogy(N,CPU_ass, label = "CPU_assemble", marker='x')
plt.legend()
plt.grid()
plt.title("Runtime GPU assemble vs CPU assemble")
plt.xlabel("length of vector")
plt.ylabel("time[s]")
plt.savefig("Bilder/runtime_assemble_GPU_vs_assemble_CPU")
