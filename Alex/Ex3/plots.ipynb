# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # strided memory accses

# %%
N = np.linspace(1, 62, num=62)
timeAll = [2.507200, 2.671600, 2.436200, 2.202400, 1.873300, 1.741100, 1.367400, 1.433100, 1.400700, 1.339800, 1.139200, 1.231100, 1.151100, 1.134700, 0.940200, 1.067100, 1.071900, 1.075100, 0.991100, 1.022700, 0.980100, 0.963300, 0.875600, 0.593600, 0.578800, 0.571000, 0.509300, 0.514000, 0.491400, 0.465000, 0.377900, 0.441300, 0.450800, 0.454700, 0.442000, 0.442200, 0.433800, 0.423200, 0.403600, 0.407600, 0.408700, 0.404100, 0.390900, 0.391300, 0.389100, 0.379400, 0.374400, 0.367400, 0.356400, 0.354200, 0.345800, 0.335400, 0.326700, 0.320300, 0.309000, 0.303300, 0.300300, 0.291000, 0.282200, 0.274100, 0.268200, 0.257500]
plt.plot(N,timeAll)
plt.grid()
plt.ylabel('time[ms]')
plt.xlabel('k-factor')
plt.title("Time to calculate the strided memory access")
plt.savefig("Bilder/Runtime_stride")

c = 0
NByte = 1e8 
BanGB =[]
for i in N:
    #print((8*NByte/(timeAll[c])*i)*1e-9)
    BanGB.append((8*NByte/(timeAll[c])*i)*1e-9)
    c = c + 1

plt.figure()
plt.plot(N,BanGB)
plt.grid()
plt.ylabel('effective Bandwidth [GB/sec]')
plt.xlabel('k-factor')
plt.title("effective Bandwidth vs k")
plt.savefig("Bilder/Bandwidth_stride")

# %% [markdown]
# # offset memory accses

# %%
N = np.linspace(1, 62, num=62)
timeAll = [2.355500, 2.354500, 2.381000, 2.685600, 2.689700, 2.684800, 2.768900, 2.682500, 2.679300, 2.676800, 2.412800, 2.672400, 2.678700, 1.956500, 1.715400, 1.803600, 1.804000, 1.797000, 1.899900, 1.846700, 1.607100, 1.310600, 1.106000, 1.099900, 1.100800, 1.108200, 1.158000, 1.102700, 1.105300, 1.104000, 1.001500, 1.090700, 1.091400, 1.087800, 1.130500, 1.120000, 1.119000, 1.120900, 1.130800, 1.112300, 1.106200, 1.108900, 1.130200, 1.113700, 1.113100, 1.115100, 1.033500, 1.094500, 1.099300, 1.100000, 1.128400, 1.114900, 1.113000, 1.115900, 1.085900, 1.108700, 1.112600, 1.109300, 1.159000, 1.103800, 1.107000, 1.108300]
plt.plot(N,timeAll)
plt.grid()
plt.ylabel('time[ms]')
plt.xlabel('k-factor')
plt.title("Time to calculate the strided memory access")
plt.savefig("Bilder/Runtime_offset")

c = 0
NByte = 1e8 
BanGB =[]
for i in N:
    #print((8*NByte/(timeAll[c])*i)*1e-9)
    BanGB.append((8*NByte/(timeAll[c])*i)*1e-9)
    c = c + 1

plt.figure()
plt.plot(N,BanGB)
plt.grid()
plt.ylabel('effective Bandwidth [GB/sec]')
plt.xlabel('k-factor')
plt.title("effective Bandwidth vs k")
plt.savefig("Bilder/Bandwidth_offset")
