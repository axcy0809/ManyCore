# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = [10,100,1000,10000,100000,1000000,10000000,100000000]
timeAll = [7.80125,7.58165,7.8174,8.22262,8.14841,7.9138,12.0587,29.637]
plt.plot(N,timeAll)
plt.grid()
plt.ylabel('time[ms]')
plt.xlabel('length of array[N]')
plt.title("Time to allocate and free")
plt.savefig("Bilder/Time_to_allocate_and_free")

# %%
N = [100,300,1000,3000,10000,30000,100000]
timeAll = [21.6434,21.2801,20.7999,20.12,20.1156,20.115,22.5097]
plt.plot(N,timeAll)
plt.grid()
plt.ylabel('time[ms]')
plt.xlabel('length of array [N]')
plt.title("Time to Sum two vectors")
plt.savefig("Bilder/Time_to_Sum")

# %%
N = [16,32,64,128,256,512,1024]
timeAll = [132.735, 49.011, 28.539, 24.9809, 25.8159, 23.0332, 25.3201]
plt.plot(N,timeAll)
plt.grid()
plt.ylabel('time[ms]')
plt.xlabel('number of grid size and block size')
plt.title("Time Diff size")
plt.savefig("Bilder/Diff_size")

# %% [markdown]
# ### Dot Product
# s = 10

# %%
N = [10,100,1000,10000,100000,1000000,10000000,30000000,50000000,100000000]
timea = [23.8471,24.804,21.2087,22.4754,20.8162,26.4995,20.0359,27.4963,40.8553,63.4607]
timeb = [19.0194,19.2184,22.169,22.3425,18.3416,23.6876,25.1247,23.7304,40.7659,63.6312]
timec = [23.6022,19.3121,20.5161,24.7904,19.0556,20.5469,24.6686,22.1535,53.8341,65.7154]
plt.semilogx(N,timea,label = " a) 2GPUs")
plt.semilogx(N,timeb,label = " b) GPUs and CPU")
plt.semilogx(N,timec,label = " c) atomicAdd")
plt.grid()
plt.legend()
plt.ylabel('time[ms]')
plt.xlabel('length of array [N]')
plt.title("Dot Product")
plt.savefig("Bilder/Dot_Prod")
